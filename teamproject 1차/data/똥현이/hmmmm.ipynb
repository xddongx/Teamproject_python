# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns   

Location = './data.csv'
data = pd.read_csv(Location,index_col=0, encoding='UTF8')
data
# Out:
#        대출일반   대출주택      졸업자수      사교육비          인구         자가용        직장가입자  \
# 2000    NaN    NaN       NaN       NaN  47008111.0         NaN          NaN
# 2001    NaN    NaN       NaN       NaN  47370164.0         NaN          NaN
# 2002    NaN    NaN       NaN       NaN  47644736.0         NaN          NaN
# 2003    NaN    NaN       NaN       NaN  47892330.0         NaN          NaN
# 2004    NaN    NaN       NaN       NaN  48082519.0         NaN          NaN
# 2005    NaN    NaN       NaN       NaN  48184561.0         NaN          NaN
# 2006    NaN    NaN       NaN       NaN  48438292.0         NaN          NaN
# 2007    NaN    NaN       NaN  200400.0  48683638.0         NaN          NaN
# 2008    NaN    NaN       NaN  209095.0  49054708.0         NaN          NaN
# 2009    NaN    NaN       NaN  216259.0  49307835.0         NaN   75391264.0
# 2010    NaN    NaN       NaN  208718.0  49554112.0         NaN   88694835.0
# ...

# %%
data.iloc[:,:10]
# Out:
#        대출일반   대출주택      졸업자수      사교육비          인구         자가용        직장가입자  \
# 2000    NaN    NaN       NaN       NaN  47008111.0         NaN          NaN
# 2001    NaN    NaN       NaN       NaN  47370164.0         NaN          NaN
# 2002    NaN    NaN       NaN       NaN  47644736.0         NaN          NaN
# 2003    NaN    NaN       NaN       NaN  47892330.0         NaN          NaN
# 2004    NaN    NaN       NaN       NaN  48082519.0         NaN          NaN
# 2005    NaN    NaN       NaN       NaN  48184561.0         NaN          NaN
# 2006    NaN    NaN       NaN       NaN  48438292.0         NaN          NaN
# 2007    NaN    NaN       NaN  200400.0  48683638.0         NaN          NaN
# 2008    NaN    NaN       NaN  209095.0  49054708.0         NaN          NaN
# 2009    NaN    NaN       NaN  216259.0  49307835.0         NaN   75391264.0
# 2010    NaN    NaN       NaN  208718.0  49554112.0         NaN   88694835.0
# ...

# %%
data.iloc[:,10:21]
# Out:
#                수입  실질국내총생산(GDP)  1인당주거면적  고등교육이수율    원자료    e러닝시장규모  문화여가지출률  \
# 2000  160481015.0           NaN      NaN     23.9  26.80        NaN      NaN
# 2001  141097821.0      947394.8      NaN     24.2  19.84        NaN      NaN
# 2002  152126153.0     1020582.4      NaN     26.0  31.20        NaN      NaN
# 2003  178826657.0     1052703.1      NaN     29.5  32.52  1077041.0      NaN
# 2004  224462687.0     1107416.2      NaN     30.5  43.45  1298484.0      NaN
# 2005  261238264.0     1155129.7      NaN     31.6  61.13  1470817.0      NaN
# 2006  309382632.0     1215939.5     26.2     32.9  61.05  1617797.0     4.16
# 2007  356845733.0     1286458.5      NaN     34.6  96.00  1727057.0     4.13
# 2008  435274737.0     1325219.3     27.8     36.6  44.60  1870475.0     4.00
# 2009  323084521.0     1335724.3      NaN     38.7  79.36  2091033.0     4.04
# 2010  425212160.0     1426618.0     28.5     39.7  91.38  2245833.0     4.25
# ...

# %%
data.iloc[:,21:30]
# Out:
#       라디오 (%)  신문 (%)  유소년부양비  노년부양비  노령화지수      사망자수  신혼부부수(합계)  \
# 2000      NaN     NaN    29.4   10.1   34.3  248740.0        NaN
# 2001      NaN     NaN    29.0   10.5   36.2  243813.0        NaN
# 2002      NaN     NaN    28.5   11.0   38.6  247524.0        NaN
# 2003      NaN     NaN    27.9   11.5   41.1  246463.0        NaN
# 2004      NaN     NaN    27.3   12.0   43.8  246220.0        NaN
# 2005      NaN     NaN    26.6   12.5   46.8  245874.0        NaN
# 2006      NaN     NaN    25.7   13.0   50.4  244162.0        NaN
# 2007      NaN     NaN    24.8   13.5   54.6  246482.0        NaN
# 2008      NaN     NaN    23.8   14.0   58.8  246113.0        NaN
# 2009     20.2    22.2    22.9   14.4   62.9  246942.0        NaN
# 2010     16.2    18.5    22.0   14.8   67.2  255405.0        NaN
# 2011     14.8    16.5    21.2   15.0   71.0  257396.0        NaN
# 2012     12.5    12.2    20.6   15.6   76.1  267221.0        NaN
# ...

# %%
data.iloc[:,30:]
# Out:
#       주택소유 신혼부부 수  실업률  1인가구 비율   출생아수(명)   혼인건수(건)  주택매매가격동향    출산율
# 2000          NaN  4.4     15.5       NaN       NaN       NaN  1.480
# 2001          NaN  4.0      NaN       NaN       NaN       NaN  1.309
# 2002          NaN  3.3      NaN       NaN       NaN       NaN  1.178
# 2003          NaN  3.6      NaN       NaN       NaN       NaN  1.191
# 2004          NaN  3.7      NaN       NaN       NaN       NaN  1.164
# 2005          NaN  3.7     20.0       NaN       NaN       NaN  1.085
# 2006          NaN  3.5      NaN       NaN       NaN       NaN  1.132
# 2007          NaN  3.2      NaN       NaN       NaN       NaN  1.259
# 2008          NaN  3.2      NaN       NaN       NaN       NaN  1.192
# 2009          NaN  3.6      NaN       NaN       NaN       NaN  1.149
# 2010          NaN  3.7     23.9  470171.0  326104.0       1.9  1.226
# 2011          NaN  3.4      NaN  471265.0  329087.0       6.9  1.244
# 2012          NaN  3.2      NaN  484550.0  327073.0       0.0  1.297
# ...

# %%
data.isna().sum()
# Out:
# 대출일반             11
# 대출주택             11
# 졸업자수             13
# 사교육비              8
# 인구                1
# 자가용              15
# 직장가입자            12
# 지역가입자            12
# 사회단체참여율          13
# 수출                1
# 수입                1
# 실질국내총생산(GDP)      2
# 1인당주거면적          12
# 고등교육이수율           1
# 원자료               1
# e러닝시장규모           4
# 문화여가지출률           7
# 지니계수             12
# 다문화출생아수           9
# 전국 이혼건수           1
# TV (%)           10
# 라디오 (%)          10
# 신문 (%)           10
# 유소년부양비            1
# 노년부양비             1
# 노령화지수             1
# 사망자수              1
# 신혼부부수(합계)        16
# 초혼부부 평균 출산자녀수    16
# 맞벌이 부부 수         16
# 주택소유 신혼부부 수      16
# 실업률               1
# 1인가구 비율          13
# 출생아수(명)          11
# 혼인건수(건)          11
# 주택매매가격동향         11
# 출산율               1
# dtype: int64

# %%
del data['인터넷 (%)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '인터넷 (%)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-486-369e1da86ecf> in <module>
# ----> 1 del data['인터넷 (%)']
#
# ...

# %%
del data['스마트폰 (%)']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '스마트폰 (%)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-487-f69caeb704ab> in <module>
# ----> 1 del data['스마트폰 (%)']
#
# ...

# %%
plt.figure(figsize=(50,50))
sns.heatmap(data = data.corr(), annot=True, 
fmt = '.2f', linewidths=.5, cmap='Blues')
# Out:
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 52636 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 48152 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51452 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
df = data.corr().tail(1)
df
# Out:
#          대출일반      대출주택      졸업자수      사교육비       인구       자가용     직장가입자  \
# 출산율 -0.126051  0.550435 -0.294195  0.023456 -0.46516 -0.991157  0.210195
#
#         지역가입자   사회단체참여율        수출  ...  신혼부부수(합계)  초혼부부 평균 출산자녀수  맞벌이 부부 수  \
# 출산율  0.319612  0.138639 -0.353601  ...   0.994766        0.97201  0.489016
#
#      주택소유 신혼부부 수       실업률   1인가구 비율   출생아수(명)   혼인건수(건)  주택매매가격동향  출산율
# 출산율     0.979049  0.239437 -0.709965  0.972442  0.891542  0.233502  1.0
#
# [1 rows x 37 columns]

# %%
df.iloc[:,:11]
# Out:
#          대출일반      대출주택      졸업자수      사교육비       인구       자가용     직장가입자  \
# 출산율 -0.126051  0.550435 -0.294195  0.023456 -0.46516 -0.991157  0.210195
#
#         지역가입자   사회단체참여율        수출        수입
# 출산율  0.319612  0.138639 -0.353601 -0.311258

# %%
df.iloc[:,11:20]
# Out:
#      실질국내총생산(GDP)   1인당주거면적   고등교육이수율       원자료   e러닝시장규모   문화여가지출률      지니계수  \
# 출산율      -0.32355 -0.032865 -0.480692 -0.124035 -0.231349 -0.813402  0.223197
#
#       다문화출생아수  전국 이혼건수
# 출산율  0.448696    0.0856

# %%
df.iloc[:,20:31]
# Out:
#        TV (%)  라디오 (%)    신문 (%)    유소년부양비     노년부양비     노령화지수      사망자수  \
# 출산율  0.408946  0.17298  0.445196  0.420838 -0.519568 -0.480138 -0.425145
#
#      신혼부부수(합계)  초혼부부 평균 출산자녀수  맞벌이 부부 수  주택소유 신혼부부 수
# 출산율   0.994766        0.97201  0.489016     0.979049

# %%
df.iloc[:,31:]
# Out:
#           실업률   1인가구 비율   출생아수(명)   혼인건수(건)  주택매매가격동향  출산율
# 출산율  0.239437 -0.989801  0.972442  0.891542  0.233502  1.0

# %%
data.iloc[0]['1인가구 비율'] = 15.5

# %%
data.loc[2005]['1인가구 비율'] =20

# %%
data.loc[2010]['1인가구 비율']=23.9

# %%
data['1인가구 비율']
# Out:
# 2000    15.5
# 2001     NaN
# 2002     NaN
# 2003     NaN
# 2004     NaN
# 2005    20.0
# 2006     NaN
# 2007     NaN
# 2008     NaN
# 2009     NaN
# 2010    23.9
# 2011     NaN
# 2012     NaN
# 2013     NaN
# 2014     NaN
# 2015    27.4
# 2016    28.1
# 2017    28.7
# 2018    29.2
# 2019     NaN
# Name: 1인가구 비율, dtype: float64

# %%
data.to_csv('data.csv', index=True)
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-477-ba4fe4ffd7de> in <module>
# ----> 1 data.to_csv('data.csv', index=True)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
#     184             )
#     185             close = True
#
# ...

# %%
data = pd.read_csv('data.csv', index_col=0)

# %%
X = data.where(pd.notnull(data), data.median(), axis='columns').copy()
print(X.shape)
X.isna().sum()
X
# Out:
# (20, 37)
#        대출일반   대출주택      졸업자수      사교육비          인구         자가용        직장가입자  \
# 2000   6.75   6.50  566324.0  192623.5  47008111.0  20984258.0  165315475.0
# 2001   6.75   6.50  566324.0  192623.5  47370164.0  20984258.0  165315475.0
# 2002   6.75   6.50  566324.0  192623.5  47644736.0  20984258.0  165315475.0
# 2003   6.75   6.50  566324.0  192623.5  47892330.0  20984258.0  165315475.0
# 2004   6.75   6.50  566324.0  192623.5  48082519.0  20984258.0  165315475.0
# 2005   6.75   6.50  566324.0  192623.5  48184561.0  20984258.0  165315475.0
# 2006   6.75   6.50  566324.0  192623.5  48438292.0  20984258.0  165315475.0
# 2007   6.75   6.50  566324.0  200400.0  48683638.0  20984258.0  165315475.0
# 2008   6.75   6.50  566324.0  209095.0  49054708.0  20984258.0  165315475.0
# 2009   6.75   6.50  566324.0  216259.0  49307835.0  20984258.0   75391264.0
# 2010   6.75   6.50  566324.0  208718.0  49554112.0  20984258.0   88694835.0
# ...

# %%
X_data = X.iloc[:,:36]
y = X.iloc[:,-1]
y
# Out:
# 2000    1.480
# 2001    1.309
# 2002    1.178
# 2003    1.191
# 2004    1.164
# 2005    1.085
# 2006    1.132
# 2007    1.259
# 2008    1.192
# 2009    1.149
# 2010    1.226
# 2011    1.244
# 2012    1.297
# 2013    1.187
# 2014    1.205
# 2015    1.239
# 2016    1.172
# 2017    1.052
# 2018    0.977
# 2019    1.191
# Name: 출산율, dtype: float64

# %% [markdown]
# # SVR

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler # kmean, PCA는 전처리에 민감하다.


X_train, X_test, y_train, y_test = train_test_split(X_data, y, random_state=0)

scaler=MinMaxScaler().fit(X_train) # 이렇게 연결하는 것을  chaining
X_train_scaled=scaler.transform(X_train)

svm=SVR()
svm.fit(X_train_scaled, y_train)

X_test_scaled=scaler.transform(X_test) # 테스트데이터도 해준다.

print('테스트 점수 : {:.2f}'.format(svm.score(X_test_scaled, y_test)))
# Out:
# 테스트 점수 : 0.43
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# 격자 : 그물망
from sklearn.model_selection import GridSearchCV

param_grid={'C':[0.001,0.01,0.1,1,10,100], 
           'gamma':[0.001,0.01,0.1,1,10,100]}

grid=GridSearchCV(SVR(), param_grid=param_grid, cv=5)
grid.fit(X_train_scaled, y_train)
print('최상의 교차 검증 정확도 : {:.2f}'.format(grid.best_score_))
print('테스트 점수 : {:.2f}'.format(grid.score(X_test_scaled,y_test)))
print('최적의 매개변수 : ',grid.best_params_)
# Out:
# 최상의 교차 검증 정확도 : -1.95
# 테스트 점수 : -0.01
# 최적의 매개변수 :  {'C': 0.001, 'gamma': 100}

# %%
from sklearn.pipeline import Pipeline

# 참조 : 파라미터 전달 이름을 뭊여준다.
pipe = Pipeline([('scaler', MinMaxScaler()),('pca',PCA()), ('svm',SVR())])
pipe.fit(X_train, y_train)
print(pipe.score(X_train, y_train))
print('테스트 점수 : {:.2f}'.format(pipe.score(X_test, y_test)))
# Out:
# 0.40784376617235063
# 테스트 점수 : 0.31
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# 격자 : 그물망
# pipeline + GridSearchCV은 다양한 테스트 문제를 해결
from sklearn.model_selection import GridSearchCV

# ragularization 규제 : 과적합 방지
param_grid={'pca__n_components':[0.001,0.01,0.1,1,10],
    'svm__C':[0.001,0.01,0.1,1,10,100], # 처음엔 대충 결정되면 그거에서 좀더 작게
           'svm__gamma':[0.001,0.01,0.1,1,10,100]}

grid=GridSearchCV(pipe, param_grid=param_grid, cv=5)
grid.fit(X_train_scaled, y_train)
print('최상의 교차 검증 정확도 : {:.2f}'.format(grid.best_score_))
print('테스트 점수 : {:.2f}'.format(grid.score(X_test_scaled,y_test)))
print('최적의 매개변수 : ',grid.best_params_)
# Out:
# 최상의 교차 검증 정확도 : -1.95
# 테스트 점수 : -0.01
# 최적의 매개변수 :  {'pca__n_components': 10, 'svm__C': 0.001, 'svm__gamma': 100}

# %% [markdown]
# # ?

# %%
# PCA : Principle Component Analysis 주성분 분석
# 모델 입력 전단에서 특징 추출(noise 제거)
# PCA의 결과를 모뎅릐 변수로 추가하면 정확도 상승
import numpy as np
from sklearn.decomposition import PCA

# 주성분을 2개로 하라
pca = PCA(n_components=10)
pca.fit(X_data)
print(pca.explained_variance_ratio_) # 설명력
# 차원축소후에 분석을 하면 좋은점
# noise 제거
# 속도개선
# 차원의 저주(너무 차원이 많으면해결이 안됀다) => 복잡한 문제를 해결
# Out:
# [9.74059911e-01 1.91347057e-02 6.77795840e-03 1.90236267e-05
#  4.67255790e-06 2.65996355e-06 9.48763058e-07 1.04443731e-07
#  1.30590626e-08 1.38991804e-09]

# %%
print(pca.explained_variance_) # 분산이 큰것이 주성분
print(pca.noise_variance_)
# Out:
# [4.30401943e+16 8.45493631e+14 2.99493535e+14 8.40585451e+11
#  2.06463481e+11 1.17534195e+11 4.19224176e+10 4.61499179e+09
#  5.77032876e+08 6.14154653e+07]
# 4908331.439962404

# %%
# svd : 희소행렬 특징추출 , 비정방행렬인 경우 사용
# randomized : 500X500이상이면
# arpack : 0이 많이 나오니까 0을 줄여서  출력하라
pca =PCA(n_components=10, svd_solver='full') # 'randomized', arpack
# singular value decomposition
pca.fit(X_data)
print(pca.explained_variance_ratio_)
# Out:
# [9.74059911e-01 1.91347057e-02 6.77795840e-03 1.90236267e-05
#  4.67255790e-06 2.65996355e-06 9.48763058e-07 1.04443731e-07
#  1.30590626e-08 1.38991804e-09]

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X_data, y, random_state=42)
print(type(X_train))
print(X_train.shape)
print(X_test.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (15, 36)
# (5, 36)

# %%
from sklearn.svm import SVR
svm=SVR(C=10)
svm.fit(X_train, y_train)
print('테스트 세트 정화도 : {:.2f}'.format(svm.score(X_test,y_test)))
# Out:
# 테스트 세트 정화도 : -0.61
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
from sklearn.preprocessing import MinMaxScaler
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
svm.fit(X_train_scaled, y_train)
print('스케일 조정된 테스트 세트의 정확도 : {:.2f}'.format(svm.score(X_test_scaled,y_test)))
# Out:
# 스케일 조정된 테스트 세트의 정확도 : -0.27
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %% [markdown]
# # ?

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(X_data)
X_scaled=scaler.transform(X_data)

# %%
pca = PCA(n_components=5)
pca.fit(X_scaled)
## 2개의 주성분을 출력
X_pca=pca.transform(X_scaled)
print(pca.explained_variance_ratio_)

# 569,30, 28개의 특성을 제거
print('원본 데이터 형태 : {}'.format(str(X_scaled.shape)))
print('축소된 데이터 형태 : {}'.format(str(X_pca.shape)))

plt.plot(np.cumsum(pca.explained_variance_ratio_)) # elbow를 시각적으로 확인
# Out:
# [0.33493525 0.18187766 0.15311561 0.07671565 0.05767804]
# 원본 데이터 형태 : (20, 36)
# 축소된 데이터 형태 : (20, 5)

# %%
plt.plot(pca.explained_variance_ratio_, 'bo-')

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler() # 정규화
scaler.fit(X_train)
X_train_scaled = scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

from sklearn.decomposition import PCA
pca = PCA(n_components=6)
pca.fit(X_train_scaled)
X_t_train = pca.transform(X_train_scaled)
X_t_test = pca.transform(X_test_scaled)
svm.fit(X_t_train, y_train)
print('SVM 테스트 정확도 : {:2f}'.format(svm.score(X_t_test, y_test)))

# 가성비 : 
# 6 : 92%   9: 94%,   15: 94%,   20: 95%,   30:97%
# Out:
# SVM 테스트 정확도 : -0.612358
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
print('PCA 주성분 형태 : {}'.format(pca.components_.shape))
# 6x30  주성분을 30개의 변수가 설명 -> 주성분 축 : 명명
# 변수의 기여도를 보고 명명식
# Out:
# PCA 주성분 형태 : (6, 36)

# %%
print('PCA 주성분 : \n{}'.format(pca.components_))
# Out:
# PCA 주성분 :
# [[-1.93603598e-01 -3.91018627e-02  1.41469560e-02 -1.06043616e-01
#    2.55759768e-01  3.86534145e-02  7.94722850e-02  7.49349303e-02
#    9.97707782e-02  2.23428490e-01  2.08222020e-01  2.56334098e-01
#    1.05093772e-01  2.46918292e-01  4.00099705e-02  2.50909951e-01
#    2.24428883e-01 -1.65425520e-02 -2.21824770e-02 -1.93669715e-01
#   -1.35149207e-01 -9.35456187e-02 -1.19202584e-01 -2.44988086e-01
#    2.63986451e-01  2.66402757e-01  2.68480050e-01 -1.54699393e-01
#   -1.73652982e-01  7.97683235e-02 -1.62334357e-01  3.71603723e-02
#    1.12432277e-01 -1.82147486e-01 -1.59835780e-01 -5.49540327e-02]
#  [ 7.07809109e-02  1.07872163e-01 -1.36890506e-01  1.79130818e-01
#    1.28527101e-01 -3.96820656e-02 -2.35197955e-01 -1.97158947e-01
#   -4.91936804e-03  2.05406979e-01  2.19611940e-01  1.31035919e-01
#   -2.92971177e-02  1.47912955e-01  2.99883426e-01  6.93377257e-02
#   -1.33356057e-01  2.09626942e-01  2.29490408e-01 -1.86122143e-01
# ...

# %%
plt.matshow(pca.components_, cmap='viridis')
plt.colorbar()

# %%
from sklearn.svm import SVR
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler # kmean, PCA는 전처리에 민감하다.

X_data

X_train, X_test, y_train, y_test = train_test_split(X_data, y, random_state=1)

scaler=StandardScaler().fit(X_train) # 이렇게 연결하는 것을  chaining
X_train_scaled=scaler.transform(X_train)

svm=SVR()
svm.fit(X_train_scaled, y_train)

X_test_scaled=scaler.transform(X_test) # 테스트데이터도 해준다.

print('테스트 점수 : {:.2f}'.format(svm.score(X_test_scaled, y_test)))
# Out:
# 테스트 점수 : -0.08

# %%
from sklearn.pipeline import Pipeline

# 참조 : 파라미터 전달 이름을 뭊여준다.
pipe = Pipeline([('scaler',StandardScaler()),('pca',PCA()), ('svm',SVR())])
pipe.fit(X_train, y_train)
print(pipe.score(X_train, y_train))
print('테스트 점수 : {:.2f}'.format(pipe.score(X_test, y_test)))
# Out:
# 0.6171508049512904
# 테스트 점수 : 0.12
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)

# %%
# 격자 : 그물망
# pipeline + GridSearchCV은 다양한 테스트 문제를 해결
from sklearn.model_selection import GridSearchCV

# ragularization 규제 : 과적합 방지
param_grid={'pca__n_components':[1,5,10],
    'svm__C':[0.001,0.01,0.1,1,10,100], # 처음엔 대충 결정되면 그거에서 좀더 작게
           'svm__gamma':[0.001,0.01,0.1,1,10,100]}

grid=GridSearchCV(pipe, param_grid=param_grid, cv=7)
grid.fit(X_train_scaled, y_train)
print('최상의 교차 검증 정확도 : {:.2f}'.format(grid.best_score_))
print('테스트 점수 : {:.2f}'.format(grid.score(X_test_scaled,y_test)))
print('최적의 매개변수 : ',grid.best_params_)
# Out:
# 최상의 교차 검증 정확도 : -1.17
# 테스트 점수 : -8.65
# 최적의 매개변수 :  {'pca__n_components': 1, 'svm__C': 1, 'svm__gamma': 10}
# C:\Users\ICT01_18\Anaconda3\lib\site-packages\sklearn\model_selection\_search.py:814: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
