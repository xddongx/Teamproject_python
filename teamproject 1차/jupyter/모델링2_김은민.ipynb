# %% [markdown]
# # 다중공선성 제거한 모델

# %%
import pandas as pd
import numpy as np
rdf= pd.read_csv("team2 - 복사본.csv",encoding='utf-8',index_col=0)

# %%
Y=rdf.iloc[:,:1]
X=rdf.iloc[:,1:]

# %%
# 방향성 있을 때 normalization 쓰는게 좋다 (robust, minmax, z점수, normalization )

# %%
#from sklearn.preprocessing import maxabs_scale
minmax_X = maxabs_scale(X)
minmax_Y = maxabs_scale(Y)

minmax_X.shape, minmax_Y.shape
# Out:
# ((19, 31), (19, 1))

# %%
rdf.iloc[:,1:]=minmax_X
rdf.iloc[:,:1]=minmax_Y

# %%
rdf.corr().iloc[:,0]  # y값과 상관계수 확인
# Out:
# Y     1.000000
# a    -0.546187
# b     0.351348
# c    -0.806956
# d    -0.589719
# e    -0.530373
# f    -0.307462
# g    -0.709129
# h    -0.653313
# i    -0.805866
# j    -0.566131
# k    -0.816703
# l    -0.279709
# m    -0.766230
# n    -0.694933
# o     0.567716
# p    -0.416526
# q     0.428730
# r     0.668100
# s     0.617048
# t     0.682999
# u     0.776362
# v    -0.839444
# w    -0.807482
# x    -0.711671
# y     0.314853
# z    -0.776234
# aa    0.727594
# bb    0.133825
# cc   -0.716599
# dd   -0.687933
# ee   -0.594952
# Name: Y, dtype: float64

# %%
rdf
# Out:
#            Y       a       b         c          d         e     f          g  \
# 2000  640089  558932  200400  47008111   75391264  27525025  44.8  172267511
# 2001  559934  558932  200400  47370164   75391264  27525025  44.8  150439144
# 2002  496911  558932  200400  47644736   75391264  27525025  44.8  162470528
# 2003  495036  558932  200400  47892330   75391264  27525025  44.8  193817443
# 2004  476958  558932  200400  48082519   75391264  27525025  38.8  253844672
# 2005  438707  558932  200400  48184561   75391264  27525025  38.8  284418743
# 2006  451759  558932  200400  48438292   75391264  27525025  38.8  325464848
# 2007  496822  558932  200400  48683638   75391264  27525025  39.8  371489086
# 2008  465892  558932  209095  49054708   75391264  27525025  39.8  422007328
# 2009  444849  558932  216259  49307835   75391264  27525025  39.8  363533561
# 2010  470171  558932  208718  49554112   88694835  30519406  46.6  466383762
# ...

# %%
# 다중공선성
# 상관계수가 높거나
# VIF > 10 이상이면 높다

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif = pd.DataFrame()

# %%
vif['VIF Factor']=[variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
vif['features']=X.columns
vif
# Out:
#      VIF Factor features
# 0  28763.402275        a
# 1   4839.849621        b
# 2  50726.452331        c
# 3   2641.372678        d
# 4   3538.823581        e
# 5    637.795690        f
# 6   2778.028150        g
# 7   1221.925585        h
# 8   3329.562817        i

# %%
import pandas as pd
import numpy as np

# %%
rdf= pd.read_csv("team2.csv",encoding='utf-8',index_col=0)

# %%
rdf
# Out:
#         출생아수      졸업자수      사교육비          인구        직장가입자       지역가입자  \
# 2000  640089  558932.0  200400.0  47008111.0   75391264.0  27525025.0
# 2001  559934  558932.0  200400.0  47370164.0   75391264.0  27525025.0
# 2002  496911  558932.0  200400.0  47644736.0   75391264.0  27525025.0
# 2003  495036  558932.0  200400.0  47892330.0   75391264.0  27525025.0
# 2004  476958  558932.0  200400.0  48082519.0   75391264.0  27525025.0
# 2005  438707  558932.0  200400.0  48184561.0   75391264.0  27525025.0
# 2006  451759  558932.0  200400.0  48438292.0   75391264.0  27525025.0
# 2007  496822  558932.0  200400.0  48683638.0   75391264.0  27525025.0
# 2008  465892  558932.0  209095.0  49054708.0   75391264.0  27525025.0
# 2009  444849  558932.0  216259.0  49307835.0   75391264.0  27525025.0
# 2010  470171  558932.0  208718.0  49554112.0   88694835.0  30519406.0
# 2011  471265  558932.0  201266.0  49936638.0  125900203.0  40538413.0
# ...

# %%
Y=rdf.iloc[:,:1]
X=rdf.iloc[:,1:]

# %%
from sklearn.preprocessing import minmax_scale
minmax_X = minmax_scale(X)
minmax_Y = minmax_scale(Y)
rdf.iloc[:,1:]=minmax_X
rdf.iloc[:,:1]=minmax_Y

# %%
rdf.shape
# Out:
# (19, 32)

# %%
import matplotlib
import matplotlib.pyplot as plt

print("Matplotlib version", matplotlib.__version__)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Out:
# Matplotlib version 3.1.1

# %%
fig = plt.figure()

# %%
data=pd.DataFrame()
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-12-d7002d247dfa> in <module>
#       1 plt.style.use('ggplot')
# ----> 2 pd.options.display.mpl_style = 'default'
#
# ~\Anaconda3\lib\site-packages\pandas\_config\config.py in __setattr__(self, key, val)
#     196             _set_option(prefix, val)
#     197         else:
# --> 198             raise OptionError("You can only set the value of existing options")
#     199
#     200     def __getattr__(self, key):
#
# OptionError: 'You can only set the value of existing options'
